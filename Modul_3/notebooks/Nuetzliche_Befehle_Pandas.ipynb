# %%
import pandas as pd
df = pd.read_csv("../data/Library_Usage.csv")
df
# Out:
#     Patron Type Code Patron Type Definition  Total Checkouts  Total Renewals  \
# 0                  1               JUVENILE              518               8
# 1                  1               JUVENILE               38               0
# 2                  0                  ADULT               38               4
# 3                  0                  ADULT               48              48
# 4                  1               JUVENILE               28              13
# 5                  1               JUVENILE                1               0
# 6                  1               JUVENILE              293              11
# 7                  1               JUVENILE              900               6
# 8                  1               JUVENILE             1569             801
# 9                  1               JUVENILE               45               0
# 10                 1               JUVENILE                0               0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 15 columns):
# Patron Type Code                20 non-null int64
# Patron Type Definition          20 non-null object
# Total Checkouts                 20 non-null int64
# Total Renewals                  20 non-null int64
# Age Range                       20 non-null object
# Home Library Code               20 non-null object
# Home Library Definition         20 non-null object
# Circulation Active Month        20 non-null object
# Circulation Active Year         20 non-null object
# Notice Preference Code          20 non-null object
# Notice Preference Definition    20 non-null object
# Provided Email Address          20 non-null bool
# Year Patron Registered          20 non-null int64
# Outside of County               20 non-null bool
# Supervisor District             17 non-null float64
# dtypes: bool(2), float64(1), int64(4), object(8)
# memory usage: 2.2+ KB

# %%
df.describe(include='all')
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# count          20.000000                     20        20.000000
# unique               NaN                      4              NaN
# top                  NaN               JUVENILE              NaN
# freq                 NaN                     14              NaN
# mean            1.100000                    NaN       210.850000
# std             0.788069                    NaN       404.898464
# min             0.000000                    NaN         0.000000
# 25%             1.000000                    NaN         5.500000
# 50%             1.000000                    NaN        33.000000
# 75%             1.000000                    NaN       128.000000
# max             3.000000                    NaN      1569.000000
#
#         Total Renewals     Age Range Home Library Code  \
# count         20.00000            20                20
# unique             NaN             4                14
# ...

# %%
#hier wird immer der kleinste Wert der Spalte angegeben
print(df.min())
print(df['Total Renewals'].min())
# Out:
# Patron Type Code                           0
# Patron Type Definition                 ADULT
# Total Checkouts                            0
# Total Renewals                             0
# Age Range                       0 to 9 years
# Home Library Code                         A5
# Home Library Definition                 Anza
# Circulation Active Month            December
# Circulation Active Year                 2008
# Notice Preference Code                     a
# Notice Preference Definition           email
# Provided Email Address                 False
# Year Patron Registered                  2003
# Outside of County                      False
# Supervisor District                        1
# dtype: object
# 0

# %%
df.columns
# Out:
# Index(['Patron Type Code', 'Patron Type Definition', 'Total Checkouts',
#        'Total Renewals', 'Age Range', 'Home Library Code',
#        'Home Library Definition', 'Circulation Active Month',
#        'Circulation Active Year', 'Notice Preference Code',
#        'Notice Preference Definition', 'Provided Email Address',
#        'Year Patron Registered', 'Outside of County', 'Supervisor District'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Patron Type Code                  int64
# Patron Type Definition           object
# Total Checkouts                   int64
# Total Renewals                    int64
# Age Range                        object
# Home Library Code                object
# Home Library Definition          object
# Circulation Active Month         object
# Circulation Active Year          object
# Notice Preference Code           object
# Notice Preference Definition     object
# Provided Email Address             bool
# Year Patron Registered            int64
# Outside of County                  bool
# Supervisor District             float64
# dtype: object

# %%
df.shape
# Out:
# (20, 15)
