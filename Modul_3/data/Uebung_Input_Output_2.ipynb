# %%
import pandas as pd
df = pd.read_json("../data/Library_Usage.json")
df.head()
# Out:
#    Patron Type Code Patron Type Definition  Total Checkouts  Total Renewals  \
# 0                 0                  ADULT                0               0
# 1                 0                  ADULT               31              22
# 2                 0                  ADULT                0               0
# 3                 0                  ADULT                0               0
# 4                 0                  ADULT              126              11
#
#         Age Range Home Library Code Home Library Definition  \
# 0  20 to 24 years                P1                    Park
# 1  25 to 34 years                S7                  Sunset
# 2  45 to 54 years                P1                    Park
# 3  25 to 34 years                 X            Main Library
# 4  45 to 54 years                M2                  Marina
#
#   Circulation Active Month Circulation Active Year Notice Preference Code  \
# ...

# %%
df.to_html("../data/Library_Usage.html")

# %%
import pandas as pd
url = ("https://pandas.pydata.org/pandas-docs/stable/reference/io.html")
df = pd.read_html(url)
df
# Out:
# [                                      0  \
#  0  read_pickle(filepath_or_buffer[, …])
#
#                                                     1
#  0  Load pickled pandas object (or any object) fro...  ,
#                                               0  \
#  0     read_table(filepath_or_buffer[, sep, …])
#  1       read_csv(filepath_or_buffer[, sep, …])
#  2  read_fwf(filepath_or_buffer[, colspecs, …])
#
#                                                     1
#  0        Read general delimited file into DataFrame.
#  1  Read a comma-separated values (csv) file into ...
#  2  Read a table of fixed-width formatted lines in...  ,
#                         0                                               1
#  0  read_clipboard([sep])  Read text from clipboard and pass to read_csv.,
#                                                   0  \
#  0   read_excel(io[, sheet_name, header, names, …])
#  1  ExcelFile.parse([sheet_name, header, names, …])
#
# ...

# %%
with open ("../data/Library_Usage.html", "r")as f:
    df=pd.read_html(f.read())
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/html.py in _build_doc(self)
#     720                 # try to parse the input in the simplest way
# --> 721                 r = parse(self.io, parser=parser)
#     722             try:
#
# ~/anaconda3/lib/python3.8/site-packages/lxml/html/__init__.py in parse(filename_or_url, parser, base_url, **kw)
#     938         parser = html_parser
# --> 939     return etree.parse(filename_or_url, parser, base_url=base_url, **kw)
#     940
#
# src/lxml/etree.pyx in lxml.etree.parse()
#
# src/lxml/parser.pxi in lxml.etree._parseDocument()
#
# src/lxml/parser.pxi in lxml.etree._parseDocumentFromURL()
#
# src/lxml/parser.pxi in lxml.etree._parseDocFromFile()
#
# src/lxml/parser.pxi in lxml.etree._BaseParser._parseDocFromFile()
#
# ...
